# %%
import torch
import numpy as np
import pylab as plt
# %matplotlib inline

# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport log_plotter
from log_plotter import get_data_pth, plot_runs_and_tags, plot_smooth_o1

# %%
# default
save_single = False
plt.rcParams.update({'font.size': 12})

# %%
# use for paper
save_single = True
plt.rcParams.update({'font.size': 16})

# %% [markdown]
# # MNIST gvar

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_gvar/(.*estim_sgd|.*estim_svrg)']
tag_names = ['Tacc', 'grad_bias', 'est_var', 'est_nvar']
fig_name = 'figs/mnist_gvar.png'
lg_tags = ['sgd', 'svrg', 'batch_size']
# ylim = [None]*20
ylim = [[98, 100], None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = None
no_title = True
lg_replace = [(',batch_size_', ' B='), ('sgd,', ''), (' ', ','), ('sgd', 'SGD'), ('svrg', 'SVRG')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title)
